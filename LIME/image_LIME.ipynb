# %%
import random
import ast
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision import models, transforms
import os 

from PIL import Image
from lime import lime_image
from skimage.segmentation import mark_boundaries

# %% [markdown]
# See info and class indices at
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# %% [markdown]
# # Classification function for LIME

# %% [markdown]
# Define the classification function LIME needs.
# Input: numpy array of images where each image is ndarray of shape (channel, height, width).
# Output: numpy array of shape (image index, classes) where each value in array should be probability for that image, class combination.

# %%
def prediction_function(images):
    model.eval()
    images_transformed = torch.stack(tuple(preprocess_transform(i) for i in images), dim=0)
    
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    model.eval()
    
    logits = model(images_transformed)
    preds = logits.softmax(dim=1)
    return preds.detach().cpu().numpy()

# %% [markdown]
# # Image loading and preprocessing

# %%
with open("imagenet1000_clsidx_to_labels.txt", "r", encoding="utf-8") as f:
    text = f.read()
labels_dict = ast.literal_eval(text)

# %%
def get_image(path):
    with open(os.path.abspath(path), 'rb') as f:
        with Image.open(f) as img:
            return img.convert('RGB') 
    

def get_pil_transform(): 
    transf = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224)
    ])    

    return transf

def get_preprocess_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])     
    transf = transforms.Compose([
        transforms.ToTensor(),
        normalize
    ])    

    return transf    

pill_transf = get_pil_transform()
preprocess_transform = get_preprocess_transform()

# %%
img = get_image('../data/cat_dog.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# # LIME

# %%
explainer = lime_image.LimeImageExplainer()
explanation = explainer.explain_instance(np.array(pill_transf(img)), 
                                         prediction_function,
                                         # number of labels (with highest prob) to show 
                                         top_labels=5, 
                                         # size of the neighborhood to learn the linear model
                                         num_samples=1000)
# Out:
#  13%|█▎        | 129/1000 [00:06<00:47, 18.47it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 explainer = lime_image.LimeImageExplainer()
# ----> 2 explanation = explainer.explain_instance(np.array(pill_transf(img)),
#       3                                          prediction_function,
#       4                                          # number of labels (with highest prob) to show
#       5                                          top_labels=5,
#       6                                          # size of the neighborhood to learn the linear model
#       7                                          num_samples=1000)
#
# File ~/AIMS/XAI/.venv/lib/python3.12/site-packages/lime/lime_image.py:198, in LimeImageExplainer.explain_instance(self, image, classifier_fn, labels, hide_color, top_labels, num_features, num_samples, batch_size, segmentation_fn, distance_metric, model_regressor, random_seed)
#     194     fudged_image[:] = hide_color
#     196 top = labels
# --> 198 data, labels = self.data_labels(image, fudged_image, segments,
#     199                                 classifier_fn, num_samples,
#     200                                 batch_size=batch_size)
#     202 distances = sklearn.metrics.pairwise_distances(
#     203     data,
#     204     data[0].reshape(1, -1),
#     205     metric=distance_metric
#     206 ).ravel()
#     208 ret_exp = ImageExplanation(image, segments)
#
# File ~/AIMS/XAI/.venv/lib/python3.12/site-packages/lime/lime_image.py:261, in LimeImageExplainer.data_labels(self, image, fudged_image, segments, classifier_fn, num_samples, batch_size)
#     259 imgs.append(temp)
#     260 if len(imgs) == batch_size:
# --> 261     preds = classifier_fn(np.array(imgs))
#     262     labels.extend(preds)
#     263     imgs = []
#
# Cell In[27], line 3, in prediction_function(images)
#       1 def prediction_function(images):
#       2     model.eval()
# ----> 3     images_transformed = torch.stack(tuple(preprocess_transform(i) for i in images), dim=0)
#       5     device = "cuda" if torch.cuda.is_available() else "cpu"
#       6     model.to(device)
#
# Cell In[27], line 3, in <genexpr>(.0)
#       1 def prediction_function(images):
#       2     model.eval()
# ----> 3     images_transformed = torch.stack(tuple(preprocess_transform(i) for i in images), dim=0)
#       5     device = "cuda" if torch.cuda.is_available() else "cpu"
#       6     model.to(device)
#
# File ~/AIMS/XAI/.venv/lib/python3.12/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~/AIMS/XAI/.venv/lib/python3.12/site-packages/torchvision/transforms/transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)    135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File ~/AIMS/XAI/.venv/lib/python3.12/site-packages/torchvision/transforms/functional.py:157, in to_tensor(pic)
#     155 # backward compatibility
#     156 if isinstance(img, torch.ByteTensor):
# --> 157     return img.to(dtype=default_float_dtype).div(255)
#     158 else:
#     159     return img
#
# KeyboardInterrupt:

# %%
explanation.top_labels
# Out:
# [np.int64(240), np.int64(239), np.int64(241), np.int64(238), np.int64(281)]

# %%
top_classes = [labels_dict[_label] for _label in explanation.top_labels]
print(top_classes)
# Out:
# ['Appenzeller', 'Bernese mountain dog', 'EntleBucher', 'Greater Swiss Mountain dog', 'tabby, tabby cat']

# %% [markdown]
# Overlay the mask on from LIME on the image to see which areas encourage the top prediction

# %%
image, mask = explanation.get_image_and_mask(explanation.top_labels[1],
                                              # only include superpixels contributing positively
                                             positive_only=True,
                                             # number of superpixels to show 
                                             num_features=6, 
                                             # turn off the non-explanation part
                                             hide_rest=True)
img_boundary = mark_boundaries(image/255.0, mask)
plt.imshow(img_boundary)
plt.show()

# %%
image, mask = explanation.get_image_and_mask(explanation.top_labels[1],
                                              # only include superpixels contributing positively
                                             positive_only=True,
                                             # number of superpixels to show 
                                             num_features=3, 
                                             # turn off the non-explanation part
                                             hide_rest=False)
img_boundary = mark_boundaries(image/255.0, mask)
plt.imshow(img_boundary)
plt.show()

# %% [markdown]
# Display areas also areas that contribute against the top prediction.

# %%
image, mask = explanation.get_image_and_mask(explanation.top_labels[1],
                                                         positive_only=False,
                                                         negative_only=False,
                                                         num_features=7,
                                                         hide_rest=False)
img_boundary = mark_boundaries(image/255.0, mask)
plt.imshow(img_boundary)
plt.show()

# %%
plt.imshow(mask)
plt.show()

# %%
np.unique(np.array(mask))
# Out:
# array([-1,  0,  1])

# %% [markdown]
# ## Other images

# %%
img = get_image('../data/fish.jpg')
plt.imshow(img)

explainer = lime_image.LimeImageExplainer()
explanation = explainer.explain_instance(np.array(pill_transf(img)),
                                         prediction_function,
                                         top_labels=5,
                                         num_samples=1000)

top_classes = [labels_dict[_label] for _label in explanation.top_labels]
print(top_classes)
# Out:
# 100%|██████████| 1000/1000 [00:46<00:00, 21.43it/s]
# ['tench, Tinca tinca', 'bolete', 'armadillo', 'isopod', 'mud turtle']

# %%
image, mask = explanation.get_image_and_mask(explanation.top_labels[0], 
                                             positive_only=False, 
                                             num_features=3, 
                                             hide_rest=False)
img_boundary = mark_boundaries(image/255.0, mask)
plt.imshow(img_boundary)
plt.show()

# %%
img = get_image('../data/aquarium.jpg')
plt.imshow(img)

explainer = lime_image.LimeImageExplainer()
explanation = explainer.explain_instance(np.array(pill_transf(img)), 
                                         prediction_function, 
                                         top_labels=5, 
                                         num_samples=1000)

top_classes = [labels_dict[_label] for _label in explanation.top_labels]
print(top_classes)
# Out:
# 100%|██████████| 1000/1000 [00:54<00:00, 18.46it/s]
# ['coral reef', 'scuba diver', 'rock beauty, Holocanthus tricolor', 'jellyfish', 'anemone fish']

# %%
image, mask = explanation.get_image_and_mask(explanation.top_labels[0], 
                                             positive_only=False, 
                                             num_features=10, 
                                             hide_rest=False)
img_boundary = mark_boundaries(image/255.0, mask)
plt.imshow(img_boundary)
plt.show()

# %% [markdown]
# ## Your own picture

# %%
img = get_image('../data/testy_1.jpg')
plt.imshow(img)
plt.show()

explainer = lime_image.LimeImageExplainer()
explanation = explainer.explain_instance(np.array(pill_transf(img)), 
                                         prediction_function, 
                                         top_labels=5, 
                                         num_samples=1000)

top_classes = [labels_dict[_label] for _label in explanation.top_labels]
print(top_classes)
# Out:
# 100%|██████████| 1000/1000 [01:00<00:00, 16.56it/s]
# ['horizontal bar, high bar', 'parallel bars, bars', 'ballplayer, baseball player', 'balance beam, beam', 'punching bag, punch bag, punching ball, punchball']

# %%
image, mask = explanation.get_image_and_mask(explanation.top_labels[0], 
                                             positive_only=False, 
                                             num_features=10, 
                                             hide_rest=False)
img_boundary = mark_boundaries(image/255.0, mask)
plt.imshow(img_boundary)
plt.show()

# %%
top_classes = [labels_dict[_label] for _label in explanation.top_labels]
print(top_classes)
# Out:
# ['coral reef', 'scuba diver', 'rock beauty, Holocanthus tricolor', 'jellyfish', 'anemone fish']

# %%
image, mask = explanation.get_image_and_mask(explanation.top_labels[0], 
                                             positive_only=False, 
                                             num_features=5, 
                                             hide_rest=False)
img_boundary = mark_boundaries(image/255.0, mask)
plt.imshow(img_boundary)
plt.show()
